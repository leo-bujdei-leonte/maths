# %%
#test how sparse matrices work 
# understand how to change the operation without scipy 
-what data structure you re using from simpy 
minimal way of changing it
